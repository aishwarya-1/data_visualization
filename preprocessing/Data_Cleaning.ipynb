# %% [raw]
# Data Cleaning :
# 1. Identify the np.NaN values, zero.
# 2. Find the Roadway, time interval.
# 3. Find the mean of those columns.
# 4. Replace the NaN values.

# %% [markdown]
# ##### IMPORT PACKAGES, ASSIGN DATAFRAME

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import math

# %%
sns.set(style="whitegrid", color_codes=True)
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("/home//aishwarya//Documents//ids_assignment//dataset//Traffic_Counts_2011-2012.csv")

# %%
df.shape
# Out:
# (3393, 31)

# %%
df.head()
# Out:
#    ID  GIS ID  Roadway Name         From                To Direction  \
# 0   1   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 1   2   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 2   3   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 3   4   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 4   5   15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
#
#          Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  2:00-3:00PM  \
# 0  01/09/2012             20           10           11  ...        104.0
# 1  01/10/2012             21           16            8  ...        102.0
# 2  01/11/2012             27           14            6  ...        115.0
# 3  01/12/2012             22            7            7  ...         71.0
# 4  01/13/2012             31           17            7  ...        113.0
#
#    3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  7:00-8:00PM  \
# 0        105.0        147.0        120.0         91.0         83.0
# 1         98.0        133.0        131.0         95.0         73.0
# 2        115.0        130.0        143.0        106.0         89.0
# 3        127.0        122.0        144.0        122.0         76.0
# 4        126.0        133.0        135.0        102.0        106.0
#
#    8:00-9:00PM  9:00-10:00PM  10:00-11:00PM  11:00-12:00AM
# 0         74.0          49.0           42.0           42.0
# 1         70.0          63.0           42.0           35.0
# 2         68.0          64.0           56.0           43.0
# 3         64.0          58.0           64.0           43.0
# 4         58.0          58.0           55.0           54.0
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['ID', 'GIS ID', 'Roadway Name', 'From', 'To', 'Direction', 'Date',
#        '12:00-1:00 AM', '1:00-2:00AM', '2:00-3:00AM', '3:00-4:00AM',
#        '4:00-5:00AM', '5:00-6:00AM', '6:00-7:00AM', '7:00-8:00AM',
#        '8:00-9:00AM', '9:00-10:00AM', '10:00-11:00AM', '11:00-12:00PM',
#        '12:00-1:00PM', '1:00-2:00PM', '2:00-3:00PM', '3:00-4:00PM',
#        '4:00-5:00PM', '5:00-6:00PM', '6:00-7:00PM', '7:00-8:00PM',
#        '8:00-9:00PM', '9:00-10:00PM', '10:00-11:00PM', '11:00-12:00AM'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                 int64
# GIS ID             int64
# Roadway Name      object
# From              object
# To                object
# Direction         object
# Date              object
# 12:00-1:00 AM      int64
# 1:00-2:00AM        int64
# 2:00-3:00AM        int64
# 3:00-4:00AM        int64
# 4:00-5:00AM        int64
# 5:00-6:00AM        int64
# 6:00-7:00AM        int64
# 7:00-8:00AM        int64
# 8:00-9:00AM        int64
# 9:00-10:00AM       int64
# 10:00-11:00AM      int64
# 11:00-12:00PM      int64
# 12:00-1:00PM     float64
# 1:00-2:00PM      float64
# 2:00-3:00PM      float64
# 3:00-4:00PM      float64
# 4:00-5:00PM      float64
# 5:00-6:00PM      float64
# 6:00-7:00PM      float64
# 7:00-8:00PM      float64
# 8:00-9:00PM      float64
# 9:00-10:00PM     float64
# 10:00-11:00PM    float64
# 11:00-12:00AM    float64
# dtype: object

# %%
df[274:284]
# Out:
#       ID  GIS ID  Roadway Name         From             To Direction  \
# 274  275  122461         8 AVE    BUTLER ST     DOUGLAS ST        SB
# 275  276   29766  NEW YORK AVE    BERGEN ST  ST MARCUS AVE        NB
# 276  277   29766  NEW YORK AVE    BERGEN ST  ST MARCUS AVE        NB
# 277  278   29766  NEW YORK AVE    BERGEN ST  ST MARCUS AVE        NB
# 278  279   29766  NEW YORK AVE    BERGEN ST  ST MARCUS AVE        NB
# 279  280   29487     QUINCY ST  CLASSON AVE   FRANKLIN AVE        EB
# 280  281   29487     QUINCY ST  CLASSON AVE   FRANKLIN AVE        EB
# 281  282   29487     QUINCY ST  CLASSON AVE   FRANKLIN AVE        EB
# 282  283   29487     QUINCY ST  CLASSON AVE   FRANKLIN AVE        EB
# 283  284   29487     QUINCY ST  CLASSON AVE   FRANKLIN AVE        EB
#
#            Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  2:00-3:00PM  \
# 274  01/13/2012             77           43           39  ...          NaN
# 275  01/10/2012            111           43           48  ...        438.0
# 276  01/11/2012            115           71           49  ...        423.0
# 277  01/12/2012            128           78           47  ...        406.0
# 278  01/13/2012            110           74           56  ...        441.0
# 279  01/09/2012             12            8            8  ...         37.0
# 280  01/10/2012              7            8            1  ...         35.0
# 281  01/11/2012             12            7            7  ...         49.0
# 282  01/12/2012             13            9            5  ...         35.0
# 283  01/13/2012             20           10            5  ...         43.0
#
#      3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  7:00-8:00PM  \
# 274          NaN          NaN          NaN          NaN          NaN
# 275        468.0        437.0        452.0        400.0        380.0
# 276        475.0        446.0        484.0        417.0        387.0
# 277        453.0        439.0        474.0        446.0        387.0
# 278        452.0        447.0         98.0          0.0          0.0
# 279         55.0         65.0         62.0         38.0         49.0
# 280         70.0         56.0         54.0         66.0         56.0
# 281         53.0         57.0         66.0         47.0         42.0
# 282         67.0         65.0         44.0         46.0         60.0
# 283         57.0         68.0         42.0         10.0          0.0
#
#      8:00-9:00PM  9:00-10:00PM  10:00-11:00PM  11:00-12:00AM
# 274          NaN           NaN            NaN            NaN
# 275        298.0         266.0          206.0          160.0
# 276        322.0         274.0          211.0          195.0
# 277        317.0         291.0          230.0          191.0
# 278          0.0           0.0            0.0            0.0
# 279         32.0          29.0           20.0           20.0
# 280         45.0          36.0           28.0           18.0
# 281         35.0          37.0           19.0           25.0
# 282         23.0          35.0           24.0           26.0
# 283          0.0           0.0            0.0            0.0
#
# [10 rows x 31 columns]

# %% [markdown]
# ###### TO REPLACE THE NaN, ZERO VALUES WITH MEAN OF THE STREET TRAFFIC AT THAT TIME INTERVAL:

# %%
def replace_NaN_Zero(x, i, index2):
    sum = 0;
    ctr = 0;
    for index, rows in df[i].iteritems():
        if(df['GIS ID'].loc[index]==x and not(np.isnan(df[i].loc[index])) and df[i].loc[index]!=0):
            sum = sum + df[i].loc[index]
            ctr = ctr+1;
    try:
        df[i].loc[index2] = int(math.ceil((sum/ctr)))
    except:
        #print("Exception : ", x)

# %%
li = ['12:00-1:00 AM','1:00-2:00AM', '2:00-3:00AM','3:00-4:00AM', '4:00-5:00AM','5:00-6:00AM', '6:00-7:00AM','7:00-8:00AM',
      '8:00-9:00AM','9:00-10:00AM','10:00-11:00AM','11:00-12:00PM','12:00-1:00PM', '1:00-2:00PM', '2:00-3:00PM', '3:00-4:00PM',
      '4:00-5:00PM', '5:00-6:00PM','6:00-7:00PM','7:00-8:00PM','8:00-9:00PM', '9:00-10:00PM', '10:00-11:00PM', '11:00-12:00AM']
for i in li:
    for index, rows in df[i].iteritems():
        if(np.isnan(df[i].loc[index]) or df[i].loc[index]==0):
            print(df['GIS ID'].loc[index], i, index)
            replace_NaN_Zero(df['GIS ID'].loc[index], i, index)

# %% [markdown]
# ###### TO CONVERT THE DATATYPES INTO INT32 FROM FLOAT64:

# %%
li = ['12:00-1:00 AM','1:00-2:00AM', '2:00-3:00AM','3:00-4:00AM', '4:00-5:00AM','5:00-6:00AM', '6:00-7:00AM','7:00-8:00AM',
      '8:00-9:00AM','9:00-10:00AM','10:00-11:00AM','11:00-12:00PM','12:00-1:00PM', '1:00-2:00PM', '2:00-3:00PM', '3:00-4:00PM',
      '4:00-5:00PM', '5:00-6:00PM','6:00-7:00PM','7:00-8:00PM','8:00-9:00PM', '9:00-10:00PM', '10:00-11:00PM', '11:00-12:00AM']

# %%
def to_Integer(x):
    for index, rows in df[x].iteritems():
        if(not(np.isnan(df[x].loc[index]))):
            df[x].loc[index] = int(df[x].loc[index])
            
for i in li:
     to_Integer(i)

# %%
df[li] = df[li].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-edf6278cc9bc> in <module>()
# ----> 1 df[li] = df[li].astype(int)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3460
#    3461     def astype(self, dtype, **kwargs):
# -> 3462         return self.apply('astype', dtype=dtype, **kwargs)
#    3463
#    3464     def convert(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     542     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     543         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 544                             **kwargs)
#     545
#     546     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     623
#     624                 # _astype_nansafe works fine with 1-d only
# --> 625                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     626                 values = values.reshape(self.shape)
#     627
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy)
#     685
#     686         if not np.isfinite(arr).all():
# --> 687             raise ValueError('Cannot convert non-finite values (NA or inf) to '
#     688                              'integer')
#     689
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
df.dtypes
# Out:
# ID                int64
# GIS ID            int64
# Roadway Name     object
# From             object
# To               object
# Direction        object
# Date             object
# 12:00-1:00 AM     int32
# 1:00-2:00AM       int32
# 2:00-3:00AM       int32
# 3:00-4:00AM       int32
# 4:00-5:00AM       int32
# 5:00-6:00AM       int32
# 6:00-7:00AM       int32
# 7:00-8:00AM       int32
# 8:00-9:00AM       int32
# 9:00-10:00AM      int32
# 10:00-11:00AM     int32
# 11:00-12:00PM     int32
# 12:00-1:00PM      int32
# 1:00-2:00PM       int32
# 2:00-3:00PM       int32
# 3:00-4:00PM       int32
# 4:00-5:00PM       int32
# 5:00-6:00PM       int32
# 6:00-7:00PM       int32
# 7:00-8:00PM       int32
# 8:00-9:00PM       int32
# 9:00-10:00PM      int32
# 10:00-11:00PM     int32
# 11:00-12:00AM     int32
# dtype: object

# %% [markdown]
# #### Write into a file

# %%
df.to_csv("Data_cleaned_2011.csv")

# %%
# import string
# for index,row in df['Date'].iteritems():
#     df['Date'].loc[index] = df['Date'].loc[index].replace('-', '/')
    
# for index, rows in df['GIS ID'].iteritems():
#         if(np.isnan(df[i].loc[index]) or df[i].loc[index]==0):
#             replace_NaN_Zero(df['GIS ID'].loc[index], i, index)
